# %%
# Out:
# 숫자를 입력하세요: 123497683
# 123497683은(는) 홀수입니다.

# %% [markdown]
# 짝수 홀수 알아보기

# %%
# 사용자로부터 숫자 입력 받기
num = int(input("숫자를 입력하세요: "))

# 짝수인지 홀수인지 확인하기
if num % 2 == 0:
    print(f"{num}은(는) 짝수입니다.")
else:
    print(f"{num}은(는) 홀수입니다.")
# Out:
# 숫자를 입력하세요: 674624526
# 674624526은(는) 짝수입니다.
